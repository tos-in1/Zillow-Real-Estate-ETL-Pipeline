# %% [markdown]
# Project code testing

# %%
================================ DATA GENERATION =================================

# %%
# Importing the necessary libraries
from dotenv import load_dotenv
import requests
import json
import os

# %%
--------------------------- CALLING .env INFORMATION ---------------------------

# %%
url = os.getenv("url")
API_HOST = os.getenv("API_HOST")
API_KEY = os.getenv("API_KEY")
print(url)
